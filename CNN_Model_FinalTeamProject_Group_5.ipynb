# %%
# Tej Singh, Gurleen Virk,  Matt Thompson
# Final Team Project: Music Genre and Composure Classification
# AAI 511 Group 5

# %%
# !pip install pretty_midi
# Out:
# Requirement already satisfied: pretty_midi in /usr/local/lib/python3.11/dist-packages (0.2.10)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from pretty_midi) (2.0.2)
# Requirement already satisfied: mido>=1.1.16 in /usr/local/lib/python3.11/dist-packages (from pretty_midi) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pretty_midi) (1.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mido>=1.1.16->pretty_midi) (25.0)

# %% [markdown]
# ## 1. Find and count the .mid (MIDI) files in the data directories

# %%
import numpy as np
import pandas as pd
import pretty_midi

# %%
 import os

 # Import the drive function from google.colab
 # Mount Google Drive
 from google.colab import drive
 drive.mount('/content/drive')

 # Specify the path to the data files by composer: Mozart
mozart_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart'
mozart_concertos_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart/Piano Concertos'
mozart_sonatas_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart/Piano Sonatas'
mozart_symphonies_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart/Symphonies'
mozart_Chelsea_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart/The Chelsea Notebook'

# Specify the path to the data files by composer: Chopin
chopin_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Chopin'

# Specify the path to the data files by composer: Beethoven
beethoven_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Beethoven'
beethoven_symphonies_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Beethoven/Symphonies'
beethoven_sonatas_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Beethoven/Piano Sonatas'

# Specify the path to the data files by composer: Bach
bach_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach'
bach_harp_concertos_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Harpsichord Concertos'
bach_concertos_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Concertos'
bach_artoffugue_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/TheArtOfFugue'
bach_nusicaloffering_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv1079 The Musical Offering'
bach_orchestralsuites_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv1066-1069 Orchestral Suites'
bach_goldbertvariations_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv988 The Goldberg Variations'
bach_clavier1_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv846-869 The Well Tempered Clavier Book 1'
bach_clavier2_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv870-893 The Well Tempered Clavier Book 2'
bach_sinfonias_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv787-801 Three Part Inventions (Sinfonias)'
bach_twopart_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv772-786 Two Part Inventions'
bach_matthew_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Matthew Passion'
bach_mass_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv232 Mass'
bach_400chorales_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv001- 400 Chorales'
bach_notebook_dataset_path = '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/LittleNotebook'


# Create lists of the dataset paths
mozart_dataset_path_list = [
    mozart_dataset_path,
    mozart_concertos_dataset_path,
    mozart_sonatas_dataset_path,
    mozart_symphonies_dataset_path,
    mozart_Chelsea_dataset_path
]

chopin_dataset_path_list = [
   chopin_dataset_path
]

beethoven_dataset_path_list = [
    beethoven_dataset_path,
    beethoven_symphonies_dataset_path,
    beethoven_sonatas_dataset_path
]

bach_dataset_path_list = [
    bach_dataset_path,
    bach_harp_concertos_dataset_path,
    bach_concertos_dataset_path,
    bach_artoffugue_dataset_path,
    bach_nusicaloffering_dataset_path,
    bach_orchestralsuites_dataset_path,
    bach_goldbertvariations_dataset_path,
    bach_clavier1_dataset_path,
    bach_clavier2_dataset_path,
    bach_sinfonias_dataset_path,
    bach_twopart_dataset_path,
    bach_matthew_dataset_path,
    bach_mass_dataset_path,
    bach_400chorales_dataset_path,
    bach_notebook_dataset_path
]

# Initialize a variable to store the total count
mozart_total_mid_files = 0
chopin_total_mid_files = 0
beethoven_total_mid_files = 0
bach_total_mid_files = 0

# Iterate through each Mozart path and count the .mid files
print()
for path in mozart_dataset_path_list:
    mid_file_count = 0
    if os.path.isdir(path):
        for filename in os.listdir(path):
            if filename.endswith('.mid'):
                mid_file_count += 1
        print(f"Number of .mid files in '{path}': {mid_file_count}")
        mozart_total_mid_files += mid_file_count
    else:
        print(f"Path not found or is not a directory: '{path}'")

# Print the total number of .mid files for Mozart
print()
print(f"Total number of .mid files for Mozart: {mozart_total_mid_files}")
print()


## Chopin
# Iterate through each Chopin path and count the .mid files
print()
for path in chopin_dataset_path_list:
    mid_file_count = 0
    if os.path.isdir(path):
        for filename in os.listdir(path):
            if filename.endswith('.mid'):
                mid_file_count += 1
        print(f"Number of .mid files in '{path}': {mid_file_count}")
        chopin_total_mid_files += mid_file_count
    else:
        print(f"Path not found or is not a directory: '{path}'")

# Print the total number of .mid files for Chopin
print(f"Total number of .mid files for Chopin: {chopin_total_mid_files}")
print()


## Beethoven
# Iterate through each Beethoven path and count the .mid files
print()
for path in beethoven_dataset_path_list:
    mid_file_count = 0
    if os.path.isdir(path):
        for filename in os.listdir(path):
            if filename.endswith('.mid'):
                mid_file_count += 1
        print(f"Number of .mid files in '{path}': {mid_file_count}")
        beethoven_total_mid_files += mid_file_count
    else:
        print(f"Path not found or is not a directory: '{path}'")

# Print the total number of .mid files for Beethoven
print(f"Total number of .mid files for Beethoven: {beethoven_total_mid_files}")
print()


## Bach
# Iterate through each Mozart path and count the .mid files
print()
for path in bach_dataset_path_list:
    mid_file_count = 0
    if os.path.isdir(path):
        for filename in os.listdir(path):
            if filename.endswith('.mid'):
                mid_file_count += 1
        print(f"Number of .mid files in '{path}': {mid_file_count}")
        bach_total_mid_files += mid_file_count
    else:
        print(f"Path not found or is not a directory: '{path}'")

# Print the total number of .mid files for Bach
print(f"Total number of .mid files for Bach: {bach_total_mid_files}")
print()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart': 90
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart/Piano Concertos': 36
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart/Piano Sonatas': 19
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart/Symphonies': 54
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Mozart/The Chelsea Notebook': 20
#
# Total number of .mid files for Mozart: 219
#
#
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Chopin': 136
# Total number of .mid files for Chopin: 136
#
#
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Beethoven': 133
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Beethoven/Symphonies': 34
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Beethoven/Piano Sonatas': 45
# Total number of .mid files for Beethoven: 212
#
#
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach': 130
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Harpsichord Concertos': 27
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Concertos': 25
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/TheArtOfFugue': 19
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv1079 The Musical Offering': 0
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv1066-1069 Orchestral Suites': 24
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv988 The Goldberg Variations': 32
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv846-869 The Well Tempered Clavier Book 1': 0
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv870-893 The Well Tempered Clavier Book 2': 28
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv787-801 Three Part Inventions (Sinfonias)': 15
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv772-786 Two Part Inventions': 15
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Matthew Passion': 10
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv232 Mass': 23
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/Bwv001- 400 Chorales': 519
# Number of .mid files in '/content/drive/My Drive/Colab Notebooks/Musicians/Bach/LittleNotebook': 17
# Total number of .mid files for Bach: 884

# %% [markdown]
# # Load all `.mid` files from the various Mozart dataset paths, clean the filenames by removing spaces and punctuation (except for the `.mid` extension), and store the cleaned filenames and the corresponding MIDI data.

# %% [markdown]
# ## Define a function to clean filenames

# %%
import re

# The filenames have spaces and some additional punctuation that might be helpful to remove

def clean_filename(filename):
    """
    Cleans a filename by removing spaces and punctuation, preserving the .mid extension.

    Args:
        filename: The original filename string.

    Returns:
        The cleaned filename string.
    """
    # Separate the filename and extension
    name, ext = os.path.splitext(filename)

    # Remove spaces and punctuation from the name using regex
    cleaned_name = re.sub(r'[^\w-]', '', name) # Keep alphanumeric characters and hyphens

    # Recombine the cleaned name and original extension
    cleaned_filename = cleaned_name + ext

    return cleaned_filename

# %% [markdown]
# ## Iterate through directories and load the midi files
#
# Loop through the Mozart dataset paths, read each `.mid` file, apply the cleaning function to the filename, and store the cleaned filename and the loaded MIDI data.

# %%
import pretty_midi

# Initialize a dictionary to store cleaned filenames and loaded MIDI data
mozart_midi_data = {}

# Iterate through each path in the mozart_dataset_path_list
for path in mozart_dataset_path_list:
    if os.path.isdir(path):
        # Iterate through each file in the directory
        for filename in os.listdir(path):
            # Check if the file ends with '.mid'
            if filename.endswith('.mid'):
                # Construct the full path to the MIDI file
                full_path = os.path.join(path, filename)

                try:
                    # Load the MIDI file
                    midi_data = pretty_midi.PrettyMIDI(full_path)

                    # Clean the filename
                    cleaned_filename = clean_filename(filename)

                    # Store the cleaned filename and loaded MIDI data
                    mozart_midi_data[cleaned_filename] = midi_data
                    print("Loading ", cleaned_filename) # This is here for debugging
                except Exception as e:
                    # Print an error message if the file could not be loaded
                    print(f"Error loading file '{full_path}': {e}")

# Display the number of loaded MIDI files
print()
print(f"Successfully loaded and processed {len(mozart_midi_data)} Mozart MIDI files.")
print()
# Out:
# Loading  K626Requiem04DiesIrae.mid
# Loading  K622ClarinetConcerto1mov.mid
# Loading  K626Requiem08offertoriodominejesu.mid
# Loading  K626Requiem10Sanctus.mid
# Loading  K495HornConcerton41mov.mid
# Loading  K620OvertureTheMagicFlute.mid
# Loading  K02MinuetinF.mid
# Loading  K626Requiem03tubamirum.mid
# /usr/local/lib/python3.11/dist-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Loading  FantasiainDK397.mid
# Loading  K04MinuetinF.mid
# Loading  Sonatinan224mov.mid
# Loading  K546AdagioFugueforStrings.mid
# Loading  Sonatinan33mov.mid
# Loading  Contradancen2.mid
# Loading  K317CoronationMass4mov.mid
# Loading  K5739VariationsforPianoUberDuport.mid
# Loading  K626Requiemkyrie.mid
# Loading  K191BassoonConcerto3mov.mid
# Loading  K191BassoonConcerto1mov.mid
# Loading  K393Solfeggin3.mid
# Loading  AdagioinBflat.mid
# Loading  K495HornConcerton43mov.mid
# Loading  Sonatinan31mov.mid
# Loading  K314FluteConcerton23mov.mid
# Loading  K618AveVerumCorpus.mid
# Loading  K401FugainGminor.mid
# Loading  K626Requiem06confutatis.mid
# Loading  K608FantasiaforMechanicalOrgan.mid
# Loading  K317CoronationMass5mov.mid
# Loading  K525Serenade4mov_EineKleineNatchmusik_.mid
# Loading  ApieceforPianoK176.mid
# Loading  K299FluteHarpConcerto3mov.mid
# Loading  K335LaudateDominus.mid
# Loading  K317CoronationMass6mov.mid
# Loading  K398PianoVariations_SalveTuDomine_.mid
# Loading  K427GreatMass1mov.mid
# Loading  K05MinuetforHarpsichord.mid
# Loading  K495HornConcerton42mov.mid
# Loading  K393Solfeggin2.mid
# Loading  K626Requiem09hostias.mid
# Loading  K626Requiem11Benedictus.mid
# Loading  K361Serenaden103mov.mid
# Loading  K525Serenade2mov_EineKleineNatchmusik_.mid
# Loading  K317CoronationMass1mov.mid
# Loading  K136Divertimento2mov.mid
# Loading  K299FluteHarpConcerto1mov.mid
# Loading  Contradancen3.mid
# Loading  K492Overture_LeNozzediFigaro_.mid
# Loading  K626Requiem01IntroitusKyrie.mid
# Loading  K317CoronationMass3mov.mid
# Loading  K393Solfeggin4.mid
# Loading  K136Divertimento3mov.mid
# Loading  K117OffertorioJubilateDeo.mid
# Loading  Rondo.mid
# Loading  K339VesperaesolemnesdeconfessoreVespers1movDixitDominus.mid
# Loading  AnotherpieceforPianoK176.mid
# Loading  K314FluteConcerton22mov.mid
# Loading  K622ClarinetConcerto2mov.mid
# Loading  K314FluteConcerton21mov.mid
# Loading  K317CoronationMass2mov.mid
# Loading  K594AdagioAllegroforMechanicalOrgan.mid
# Loading  K617Adagio.mid
# Loading  K622ClarinetConcerto3mov.mid
# Loading  FantasiainCK475.mid
# Loading  K626Requiem12agnusdei.mid
# Loading  K525Serenade1mov_EineKleineNatchmusik_.mid
# Loading  K525Serenade3mov_EineKleineNatchmusik_.mid
# Loading  K393Solfeggin1.mid
# Loading  Contradancen1.mid
# Loading  Sonatinan32mov.mid
# Loading  Sonatinan213mov.mid
# Loading  K191BassoonConcerto2mov.mid
# Loading  RondoinC.mid
# Loading  K299FluteHarpConcerto2mov.mid
# Loading  K626Requiem07Lacrimosa.mid
# Loading  K03AllegroinBb.mid
# Loading  K626Requiem02rextremendae.mid
# Loading  K527Overture_DonGiovanni_.mid
# Loading  K393Solfeggin5.mid
# Loading  K626Requiem05Recordare.mid
# Loading  K136Divertimento1mov.mid
# Loading  K354PianoVariations_JeSuisLindor_.mid
# Loading  K501Andantewith5VariationsforPianoDuet.mid
# Loading  VienneseSonatinasK439bn62mov.mid
# Loading  Vesperaesolemnesdeconfessore_Vespers_K3391DixitDominus.mid
# Loading  VienneseSonatinasK439bn22mov.mid
# Loading  VienneseSonatinasK439bn61mov.mid
# Loading  VienneseSonatinasK439bn24mov.mid
# Loading  VienneseSonatinasK439bn21mov.mid
# Loading  VienneseSonatinasK439bn23mov.mid
# Loading  PianoConcerton7for3PianosK2423mov_Lodron_.mid
# Loading  PianoConcerton7for3PianosK2421mov_Lodron_.mid
# Loading  PianoConcerton17K4533mov.mid
# Loading  PianoConcerton23K4882mov.mid
# Loading  PianoConcerton26K5371mov_Coronation_.mid
# Loading  PianoConcerton20K4661mov.mid
# Loading  PianoConcerton12K4141mov.mid
# Loading  PianoConcerton21K4673mov_ElviraMadigan_.mid
# Loading  PianoConcerton23K4883mov.mid
# Loading  PianoConcerton7for3PianosK2422mov_Lodron_.mid
# Loading  PianoConcerton18K4562mov_Paradis_.mid
# Loading  PianoConcerton24K4911mov.mid
# Loading  PianoConcerton12K4143mov.mid
# Loading  PianoConcerton16K4513mov.mid
# Loading  PianoConcerton25K5032mov.mid
# Loading  PianoConcerton8K2461mov.mid
# Loading  PianoConcerton18K4563mov_Paradis_.mid
# Loading  PianoConcerton6K2381mov.mid
# Loading  PianoConcerton6K2383mov.mid
# Loading  PianoConcerton20K4663mov.mid
# Loading  PianoConcerton21K4672mov_ElviraMadigan_.mid
# Loading  PianoConcerton14K4493mov.mid
# Loading  PianoConcerton8K2463mov.mid
# Loading  PianoConcerton23K4881mov.mid
# Loading  PianoConcerton24K4913mov.mid
# Loading  PianoConcerton18K4561mov_Paradis_.mid
# Loading  PianoConcerton26K5372mov_Coronation_.mid
# Loading  PianoConcerton24K4912mov.mid
# Loading  PianoConcerton26K5373mov_Coronation_.mid
# Loading  PianoConcerton14K4491mov.mid
# Loading  PianoConcerton25K5033mov.mid
# Loading  PianoConcerton25K5031mov.mid
# Loading  PianoConcerton20K4662mov.mid
# Loading  PianoConcerton16K4511mov.mid
# Loading  PianoConcerton21K4671mov_ElviraMadigan_.mid
# Loading  PianoConcerton14K4492mov.mid
# Loading  PianoSonatan16K545.mid
# Loading  PianoSonatan11K331.mid
# Loading  PianoSonatan05K283.mid
# Loading  PianoSonatan07K309.mid
# Loading  PianoSonatan19K576.mid
# Loading  PianoSonatan15K593-494.mid
# Loading  PianoSonatan08K311.mid
# Loading  PianoSonatan12K332.mid
# Loading  PianoSonatan17K547a.mid
# Loading  PianoSonatan10K330.mid
# Loading  PianoSonatan09K310.mid
# Loading  PianoSonatan14K457.mid
# Loading  PianoSonatan04K282.mid
# Loading  PianoSonatan13K333.mid
# Loading  PianoSonatan03K281.mid
# Loading  PianoSonatan06K284.mid
# Loading  PianoSonatan18K570.mid
# Loading  PianoSonatan02K280.mid
# Loading  PianoSonatan01K279.mid
# Loading  Symphonyn25K1833mov.mid
# Loading  Symphonyn29K2011mov.mid
# Loading  Symphonyn33K3192mov.mid
# Loading  Symphonyn33K3193mov.mid
# Loading  Symphonyn31K2971mov_Paris_.mid
# Loading  Symphonyn25K1832mov.mid
# Loading  Symphonyn30K2021mov.mid
# Loading  Symphonyn34K3381mov.mid
# Loading  Symphonyn33K3191mov.mid
# Loading  Symphonyn30K2023mov.mid
# Loading  Symphonyn22K1623mov.mid
# Loading  Symphonyn29K2014mov.mid
# Loading  Symphonyn34K3382mov.mid
# Loading  Symphonyn29K2012mov.mid
# Loading  Symphonyn34K3383mov.mid
# Loading  Symphonyn31K2973mov_Paris_.mid
# Loading  Symphonyn35K3851mov_Haffner_.mid
# Loading  Symphonyn30K2022mov.mid
# Loading  Symphonyn28K2001mov.mid
# Loading  Symphonyn28K2002mov.mid
# Loading  Symphonyn25K1831mov.mid
# Loading  Symphonyn25K1834mov.mid
# Loading  Symphonyn30K2024mov.mid
# Loading  Symphonyn31K2972mov_Paris_.mid
# Loading  Symphonyn22K1621mov.mid
# Loading  Symphonyn28K2003mov.mid
# Loading  Symphonyn28K2004mov.mid
# Loading  Symphonyn33K3194mov.mid
# Loading  Symphonyn5K022.mid
# Loading  Symphonyn39K5431mov.mid
# Loading  Symphonyn40K5501mov.mid
# Loading  Symphonyn40K5504mov.mid
# Loading  Symphonyn41K5512mov_Jupiter_.mid
# Loading  Symphonyn38K5042mov_Prague_.mid
# Loading  Symphonyn39K5433mov.mid
# Loading  Symphonyn36K4254mov_Linz_.mid
# Loading  Symphonyn36K4251mov_Linz_.mid
# Loading  Symphonyn39K5434mov.mid
# Loading  Symphonyn40K5503mov.mid
# Loading  Symphonyn39K5432mov.mid
# Loading  Symphonyn35K3852mov_Haffner_.mid
# Loading  Symphonyn38K5043mov_Prague_.mid
# Loading  Symphonyn38K5041mov_Prague_.mid
# Loading  Symphonyn36K4253mov_Linz_.mid
# Loading  Symphonyn41K5514mov_Jupiter_.mid
# Loading  Symphonyn35K3854mov_Haffner_.mid
# Loading  Symphonyn4K0191mov.mid
# Loading  Symphonyn37K4441mov.mid
# Loading  Symphonyn36K4252mov_Linz_.mid
# Loading  Symphonyn4K193mov.mid
# Loading  Symphonyn35K3853mov_Haffner_.mid
# Loading  Symphonyn40K5502mov.mid
# Loading  Symphonyn41K5511mov_Jupiter_.mid
# Loading  Symphonyn41K5513mov_Jupiter_.mid
# Loading  EarlyPiecesn4Minuet.mid
# Loading  EarlyPiecesn15Andantino.mid
# Loading  EarlyPiecesn3Littlemarch.mid
# Loading  EarlyPiecesn13Prelude.mid
# Loading  EarlyPiecesn1Andante.mid
# Loading  EarlyPiecesn14Rondo.mid
# Loading  EarlyPiecesn9Allegretto.mid
# Loading  EarlyPiecesn2Minuet.mid
# Loading  EarlyPiecesn16Minuet.mid
# Loading  EarlyPiecesn5CountryDance.mid
# Loading  EarlyPiecesn8Minuet.mid
# Loading  EarlyPiecesn6Llittleminuet.mid
# Loading  EarlyPiecesn10Air.mid
# Loading  EarlyPiecesn12Rondino.mid
# Loading  EarlyPiecesn17Siciliano.mid
# Loading  EarlyPiecesn20Presto.mid
# Loading  EarlyPiecesn7Countrydance.mid
# Loading  EarlyPiecesn19Giga.mid
# Loading  EarlyPiecesn11Countrydance.mid
# Loading  EarlyPiecesn18LittleSong.mid
#
# Successfully loaded and processed 219 Mozart MIDI files.

# %% [markdown]
# Loop through the Chopin dataset paths, read each `.mid` file, apply the cleaning function to the filename, and store the cleaned filename and the loaded MIDI data.

# %%
# Initialize a dictionary to store cleaned filenames and loaded MIDI data
chopin_midi_data = {}

# Iterate through each path in the mozart_dataset_path_list
for path in chopin_dataset_path_list:
    if os.path.isdir(path):
        # Iterate through each file in the directory
        for filename in os.listdir(path):
            # Check if the file ends with '.mid'
            if filename.endswith('.mid'):
                # Construct the full path to the MIDI file
                full_path = os.path.join(path, filename)

                try:
                    # Load the MIDI file
                    midi_data = pretty_midi.PrettyMIDI(full_path)

                    # Clean the filename
                    cleaned_filename = clean_filename(filename)

                    # Store the cleaned filename and loaded MIDI data
                    chopin_midi_data[cleaned_filename] = midi_data
                    print("Loading ", cleaned_filename) # This is here for debugging
                except Exception as e:
                    # Print an error message if the file could not be loaded
                    print(f"Error loading file '{full_path}': {e}")

# Display the number of loaded MIDI files
print()
print(f"Successfully loaded and processed {len(chopin_midi_data)} Chopin MIDI files.")
print()
# Out:
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo5.mid
# Loading  Etudeop10n12_Revolutionary_.mid
# Loading  NocturneNo1Opus62.mid
# Loading  NocturneNo15inFMinorOpus55-1.mid
# Loading  Etudeop10n08.mid
# Loading  Nocturneop55n1.mid
# Loading  Revolutionary.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo14.mid
# Loading  Preludeop28-15Raindrop.mid
# Loading  Etudeop25n10.mid
# Loading  Nocturneop33n4.mid
# Loading  Preluden16op28_Hades_.mid
# Loading  FantasieImpromptuop66.mid
# Loading  GrandeWaltzop18.mid
# Loading  Preluden12op28_Duel_.mid
# Loading  2Polonaisesop26n1.mid
# Loading  Etudeop10n07.mid
# Loading  Preluden05op28_Uncertainty_.mid
# Loading  Waltzop70n2.mid
# Loading  Etudeop25n02.mid
# Loading  EtudeNo2inAMinor.mid
# Loading  ScherzoNo2Opus31.mid
# Loading  Sonataop35n1.mid
# Loading  Etudeop10n04Drchew.mid
# Loading  Preluden10op28_TheNightMoth_.mid
# Loading  Preluden03op28_ThouArtSoLikeAFlower_.mid
# Loading  EtudeOp25No1.mid
# Loading  Etudeop25n03.mid
# Loading  Preluden17op28_SceneOnthePlaceofNotreDame.mid
# Loading  Preluden04op28_Suffocation_.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo15.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo4.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo13.mid
# Loading  Nocturneop32n1.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo18.mid
# Loading  Nocturneop48n1.mid
# Loading  Preluden11op28_Dragonfly_.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo8.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo10.mid
# Loading  Etudeop25n11_WinterWind_.mid
# Loading  SonataNo32ndMovScherzo.mid
# Loading  Nocturneop33n2.mid
# Loading  Preluden09op28_Vision_.mid
# Loading  Mazurkaop33n2Drchew.mid
# Loading  Preluden06op28_TollingBells_.mid
# Loading  Nocturneop09n2.mid
# Loading  Sonataop35n4.mid
# Loading  Mazurkaop67n3Drchew.mid
# Loading  Etudeop25n06.mid
# Loading  Mazurkaop68n2Drchew.mid
# Loading  Nocturneop37n2.mid
# Loading  EtudeOp10No11.mid
# Loading  Nocturneop15n2.mid
# Loading  Preluden23op28_APleasureBoat_.mid
# Loading  Etudeop10-5Blackkeys.mid
# Loading  Tarantella.mid
# Loading  Sonataop35n2.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo2.mid
# Loading  Etudeop10n11.mid
# Loading  FinaletoBMinorPainoSonata.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo17.mid
# Loading  Nocturneop48n2.mid
# Loading  Nocturneop72n1.mid
# Loading  PianoConcerton1op113mov.mid
# Loading  Scherzon1op20.mid
# Loading  Etudeop25n08.mid
# Loading  Preluden21op28_Sunday_.mid
# Loading  ImpromptFantastique.mid
# Loading  Etudeop10n03.mid
# Loading  Nocturneop32n2.mid
# Loading  Op53_PolonaiseinAflat_Heroic.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo9.mid
# Loading  Waltzop64n1.mid
# Loading  Etudeop10n06.mid
# Loading  Mazurkaop7n2.mid
# Loading  Nocturneop27n1.mid
# Loading  Etudeop25n01_HarpEtude_.mid
# Loading  Etudeop25n09.mid
# Loading  WaltzinAbOpposthBrown21.mid
# Loading  PianoConcerton23mov.mid
# Loading  Etudeop10n10.mid
# Loading  PianoConcerton21mov.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo12.mid
# Loading  Preluden01op28_Reunion_.mid
# Loading  Preluden20op28_FuneralMarch_.mid
# Loading  Nocturneop3701.mid
# Loading  Preluden24op28_TheStorm_.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo11.mid
# Loading  Etudeop10n05_BlackKey_.mid
# Loading  Balladop53.mid
# Loading  BalladeNo2inFMajor.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo7.mid
# Loading  PianoConcerton1op111mov.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo3.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo6.mid
# Loading  SonataNo31stMovAllegro.mid
# Loading  Nocturneop09n3.mid
# Loading  Preluden19op28.mid
# Loading  PolonaiseOpus40No1Military.mid
# Loading  EtudeNo7inCMajorOpus10No7.mid
# Loading  Nocturneop27n2.mid
# Loading  Preluden15op28_Raindrop_.mid
# Loading  Mazurkaop7n1.mid
# Loading  Etudeop25n07.mid
# Loading  Etudeop25n04.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo19.mid
# Loading  PianoConcerton22mov.mid
# Loading  Balladop32.mid
# Loading  Nocturneop55n2.mid
# Loading  Etudeop10n01.mid
# Loading  Etudeop10n02.mid
# Loading  TroisNouvellesEtudesOpposth.mid
# Loading  Preluden18op28_Suicide_.mid
# Loading  BarcarolleinFsharpMajor.mid
# Loading  Preluden22op28_Impatience_.mid
# Loading  Preluden14op28_Fear_.mid
# Loading  Winterwindetude.mid
# Loading  Preluden07op28_ThePolishDance_.mid
# Loading  2542Preludeopus28No16inBflatminor.mid
# Loading  EcossaiseNo2inG.mid
# Loading  Mazurkaop30n2Drchew.mid
# Loading  Scherzoop31.mid
# Loading  Preluden13op28_Loss_.mid
# Loading  Etudeop25n05.mid
# Loading  Sonataop35n3.mid
# Loading  Impromptun3op51.mid
# Loading  PianoConcerton1op112mov.mid
# Loading  Etudeop10n09.mid
# Loading  EtudeNo1.mid
# Loading  Nocturneop62n2.mid
# Loading  Preluden02op28_PresentimentofDeath_.mid
# Loading  NocturneNo18inEMajorOp62.mid
# Loading  19PolishSongsforSoloVoiceandPianoaccomplementsNo16.mid
# Loading  Preluden08op28_Desparation_.mid
# Loading  Nocturneop15n3.mid
# Loading  Etudeop25n12_TheOcean_.mid
#
# Successfully loaded and processed 136 Chopin MIDI files.

# %% [markdown]
# Loop through the Beethoven dataset paths, read each .mid file, apply the cleaning function to the filename, and store the cleaned filename and the loaded MIDI data.

# %%
# Initialize a dictionary to store cleaned filenames and loaded MIDI data
beethoven_midi_data = {}

# Iterate through each path in the mozart_dataset_path_list
for path in beethoven_dataset_path_list:
    if os.path.isdir(path):
        # Iterate through each file in the directory
        for filename in os.listdir(path):
            # Check if the file ends with '.mid'
            if filename.endswith('.mid'):
                # Construct the full path to the MIDI file
                full_path = os.path.join(path, filename)

                try:
                    # Load the MIDI file
                    midi_data = pretty_midi.PrettyMIDI(full_path)

                    # Clean the filename
                    cleaned_filename = clean_filename(filename)

                    # Store the cleaned filename and loaded MIDI data
                    beethoven_midi_data[cleaned_filename] = midi_data
                    print("Loading ", cleaned_filename) # This is here for debugging
                except Exception as e:
                    # Print an error message if the file could not be loaded
                    print(f"Error loading file '{full_path}': {e}")

# Display the number of loaded MIDI files
print()
print(f"Successfully loaded and processed {len(beethoven_midi_data)} Beethoven MIDI files.")
print()
# Out:
# Loading  Hess059ExercizioPerPianoforte.mid
# Loading  Hess073Bagatella.mid
# Loading  Anh06Rondo.mid
# Loading  PianoConcerton3op373mov.mid
# Loading  PianoSonataNo27.mid
# Loading  MarchNo3.mid
# Loading  PianoConcerton2op192mov.mid
# Loading  PianoConcerton1op151mov.mid
# Loading  Liederop48n1_Bitten_.mid
# Loading  Bagatellaop33n4.mid
# Loading  Overture_Fidelio_op72b.mid
# Loading  PianoConcerton5op731mov_Emperor_.mid
# Loading  PianoConcerton2op191mov.mid
# Loading  Bagatellaop33n2.mid
# Loading  Hess057Bagatella.mid
# Loading  Anh08Nb1Gavotte4hands.mid
# Loading  PianoConcerton3op371mov.mid
# Loading  Hess063keybKaplied.mid
# Loading  PianoConcerton2op193mov.mid
# Loading  Overture_Leonore_n3op72.mid
# Loading  PianoConcerton1op153mov.mid
# Loading  Opus045ThreeGrandesMarches.mid
# Loading  Hess061Anglaise.mid
# Loading  PianoConcerton4op582mov.mid
# Loading  Hess074Bagatella.mid
# Loading  Overture_Egmont_.mid
# Loading  Overture_Leonore_n2op72.mid
# Loading  Overture_KingStephen_.mid
# Loading  PianoConcerton3op372mov.mid
# Error loading file '/content/drive/My Drive/Colab Notebooks/Musicians/Beethoven/Anhang 14-3.mid': Could not decode key with 3 flats and mode 255
# Loading  Minuetto.mid
# Loading  Overture_CreaturesOfPrometeus_op43.mid
# Loading  Liederop48n2_DieLiebeDesNachsten_.mid
# Loading  Liederop82n1_DimmiDenMioCheMiAmi_.mid
# Loading  PianoRomanceNo50.mid
# Loading  Liederop48n4_DieEhreGottesAusDerNatur_.mid
# Loading  BagatellaFurElise.mid
# Loading  Liederop46_Adelaide_.mid
# Loading  Overture_InaugurationoftheHouse_op214.mid
# Loading  Bagatellaop33n3.mid
# Loading  Bagatellaop33n1.mid
# Loading  PianoConcerton5op732-3mov_Emperor_.mid
# Loading  Liederop99_DerMannVonWort_.mid
# Loading  Op51.mid
# Loading  FurElise.mid
# Loading  PianoConcerton4op583mov.mid
# Loading  PianoConcerton4op581mov.mid
# Loading  32Variationsonatheme.mid
# Loading  PianoConcertoNo5Mov1.mid
# Loading  AndanteinFMajor.mid
# Loading  Liederop48n3_VomTode_.mid
# Loading  PianoConcerton1op152mov.mid
# Loading  Overture_Leonore_op138n1.mid
# Loading  Liederop48n6_Busslied_.mid
# Loading  PianoConcertoNo5Mov3.mid
# Loading  PianoSonataNo273rdmov.mid
# Loading  HessA21Bagatella.mid
# Loading  Bagatellaop33n6.mid
# Loading  Op33No4.mid
# Loading  Liederop48n5_GottesMachtUndVorsehung_.mid
# Loading  PianoSonataNo2Assaivivace.mid
# Loading  Overture_Corolian_op62.mid
# Loading  PianoSonataNo28inBflat-Hammerklavier-Op1062ndMovScherzo.mid
# Loading  Bagatellaop33n5.mid
# Loading  op126SixBagatellas.mid
# Loading  SonatainBflatMajorOp106.mid
# Loading  SonataOpus81a-LesAdieux-EflatNo23.mid
# Loading  SonatinaWoO050.mid
# Loading  StringQuartetn1op181mov.mid
# Loading  WoO048Rondo.mid
# Loading  SonataOpus111CminorNo2.mid
# Loading  StringQuartetn16op1351mov.mid
# Loading  StringQuartetn2op18n24mov.mid
# Loading  StringQuartetn2op18n21mov.mid
# Loading  PianoSonatinaNo2Op49.mid
# Loading  StringQuartetn2op18n23mov.mid
# Loading  op0513Rondos.mid
# Loading  SiebenBagatelleninAMajorOpus33No4.mid
# Loading  SiebenBagatelleninFMajorOpus33No3.mid
# Loading  RondoOpus51No1.mid
# Loading  StringQuartetn1op184mov.mid
# Loading  StringQuartetn16op1352mov.mid
# Loading  WoO051Sonatina1-2movs.mid
# Loading  WoO086Scotish.mid
# Loading  WoO061aMouvementPourPiano.mid
# Loading  ViolinConcertoop612-3movs.mid
# Loading  SiebenBagatellenCMajorOpus33No2.mid
# Loading  RondoinBflat.mid
# Loading  SketchforPianoAllaMarcia.mid
# Loading  PianoSonatinainGOp79.mid
# Loading  WoO060MouvementPourPiano.mid
# Loading  StringQuartetn16op1353mov.mid
# Loading  SonatinaInC.mid
# Loading  Romancepiano.mid
# Loading  WoO055Prelude.mid
# Loading  SiebenBagatelleninDMajorOpus33No6.mid
# Loading  SonataOpus81a-LesAdieux-EflatNo1.mid
# Loading  SonataNo14Op27MoonlightSonata.mid
# Loading  Sonatinaop334mov.mid
# Loading  Sonataop781stmov.mid
# Loading  RondoOpus51No2.mid
# Loading  SonataNo14Op27SonataQuasiUnaFantasia.mid
# Loading  SiebenBagatelleninEflatMajorOpus33No1.mid
# Loading  op077Fantaisie.mid
# Loading  SonatinaFamajwoo.mid
# Loading  StringQuartetn2op18n22mov.mid
# Loading  SonataPresto.mid
# Loading  SketchforPianoAllegretto.mid
# Loading  Sonatinan1op05.mid
# Loading  WoO083SixEscotishDancesforPiano.mid
# Loading  SketchforPianoPresto.mid
# Loading  WoO061MouvementPourPiano.mid
# Loading  op119DouzeBagatellas.mid
# Loading  WoO054LustigTraurig.mid
# Loading  op089Polonaise.mid
# Loading  SevenInversionsofGodSavetheKing.mid
# Loading  SketchforPianoAllegroGiocoso.mid
# Loading  SiebenBagatelleninCMajorOpus33No5.mid
# Loading  WoO081Allemande.mid
# Loading  StringQuartetn16op1354mov.mid
# Loading  SechsVariationen.mid
# Loading  WoO049Rondo.mid
# Loading  WoO052Bagatella.mid
# Loading  Preludes2ThroughMajorkeys39.mid
# Loading  SketchforPianoAllegro.mid
# Loading  StringQuartetn1op182mov.mid
# Loading  ViolinConcertoop611mov.mid
# Loading  WoO010SixMenuetsforOrchestra.mid
# Loading  StringQuartetn1op183mov.mid
# Loading  WoO082Menuet.mid
# Loading  SonataOpus111CminorNo1.mid
# Loading  Rageoveralostpennny.mid
# Loading  WoO056Bagatella.mid
# Loading  Symphonyop93n83mov.mid
# Loading  Symphonyop68n62mov_Pastorale_.mid
# Loading  Symphonyn41mov.mid
# Loading  Symphonyn72mov.mid
# Loading  Symphonyn34mov_Eroica_.mid
# Loading  Symphonyn43mov.mid
# Loading  Symphonyop125n91mov_Choral_.mid
# Loading  Symphonyop125n93mov_Choral_.mid
# Loading  Symphonyop125n92mov_Choral_.mid
# Loading  Symphonyn73mov.mid
# Loading  Symphonyop125n94mov_Choral_.mid
# Loading  Symphonyop68n6_Pastorale_.mid
# Loading  Symphonyop68n61mov_Pastorale_.mid
# Loading  Symphonyn42mov.mid
# Loading  Symphonyop93n84mov.mid
# Loading  Symphonyn11mov.mid
# Loading  Symphonyn2op362mov.mid
# Loading  Symphonyn74mov.mid
# Loading  Symphonyop93n82mov.mid
# Loading  Symphonyn14mov.mid
# Loading  Symphonyn12mov.mid
# Loading  Symphonyn44mov.mid
# Loading  Symphonyn71mov.mid
# Loading  Symphonyn31mov_Eroica_.mid
# Loading  Symphonyn2op364mov.mid
# Loading  Symphonyn2op361mov.mid
# Loading  Symphonyn5op671mov.mid
# Loading  Symphonyn32mov_Eroica_.mid
# Loading  Symphonyn33mov_Eroica_.mid
# Loading  Symphonyop93n81mov.mid
# Loading  Symphonyop68n63mov_Pastorale_.mid
# Loading  Symphonyn2op363mov.mid
# Loading  Symphonyn5op673-4mov.mid
# Loading  Symphonyn13mov.mid
# Loading  PianoSonatan04.mid
# Loading  PianoSonatan08op132mov_Pathetique_.mid
# Loading  PianoSonatan02.mid
# Loading  PianoSonatan06.mid
# Loading  PianoSonatan08op131mov_Pathetique_.mid
# Loading  PianoSonatan05.mid
# Loading  PianoSonatan07.mid
# Loading  PianoSonatan08op133mov_Pathetique_.mid
# Loading  PianoSonatan09.mid
# Loading  PianoSonatan01.mid
# Loading  PianoSonatan101mov.mid
# Loading  PianoSonatan03.mid
# Loading  PianoSonatan22.mid
# Loading  PianoSonatan102mov.mid
# Loading  PianoSonatan20.mid
# Loading  PianoSonatan10.mid
# Loading  PianoSonatan23op572mov_Apassionata_.mid
# Loading  PianoSonatan16.mid
# Loading  PianoSonatan14op273mov_Moonlight_.mid
# Loading  PianoSonatan24.mid
# Loading  PianoSonatan14op27_Moonlight_.mid
# Loading  Pianosonatan32op111.mid
# Loading  PianoSonatan15_Pastoral_.mid
# Loading  PianoSonatan30.mid
# Loading  PianoSonatan31op110.mid
# Loading  PianoSonatan18_TheHunt_.mid
# Loading  Pianosonatan26_LesAdieux_.mid
# Loading  PianoSonatan212mov_Waldstein_.mid
# Loading  PianoSonatan152mov_Pastoral_.mid
# Loading  PianoSonatan11.mid
# Loading  PianoSonatan13.mid
# Loading  PianoSonatan14op271mov_Moonlight_.mid
# Loading  PianoSonatan29Op106_Hammerklavier_.mid
# Loading  PianoSonatan17_Tempestat_.mid
# Loading  PianoSonatan213mov_Waldstein_.mid
# Loading  PianoSonatan211mov_Waldstein_.mid
# Loading  PianoSonatan12op26.mid
# Loading  PianoSonatan28.mid
# Loading  PianoSonatan153mov_Pastoral_.mid
# Loading  PianoSonatan23op571mov_Apassionata_.mid
# Loading  PianoSonatan23op573mov_Apassionata_.mid
# Loading  PianoSonatan25.mid
# Loading  PianoSonatan27.mid
# Loading  PianoSonatan19.mid
# Loading  PianoSonatan14op272mov_Moonlight_.mid
#
# Successfully loaded and processed 211 Beethoven MIDI files.

# %% [markdown]
# Loop through the Bach dataset paths, read each .mid file, apply the cleaning function to the filename, and store the cleaned filename and the loaded MIDI data.

# %%
# Initialize a dictionary to store cleaned filenames and loaded MIDI data
bach_midi_data = {}

# Iterate through each path in the mozart_dataset_path_list
for path in bach_dataset_path_list:
    if os.path.isdir(path):
        # Iterate through each file in the directory
        for filename in os.listdir(path):
            # Check if the file ends with '.mid'
            if filename.endswith('.mid'):
                # Construct the full path to the MIDI file
                full_path = os.path.join(path, filename)

                try:
                    # Load the MIDI file
                    midi_data = pretty_midi.PrettyMIDI(full_path)

                    # Clean the filename
                    cleaned_filename = clean_filename(filename)

                    # Store the cleaned filename and loaded MIDI data
                    bach_midi_data[cleaned_filename] = midi_data
                    print("Loading ", cleaned_filename) # This is here for debugging
                except Exception as e:
                    # Print an error message if the file could not be loaded
                    print(f"Error loading file '{full_path}': {e}")

# Display the number of loaded MIDI files
print()
print(f"Successfully loaded and processed {len(bach_midi_data)} Bach MIDI files.")
print()
# Out:
# Loading  Bwv0539PreludeandFugue.mid
# Loading  Bwv0544PreludeandFugue.mid
# Loading  Bwv0811EnglishSuiten68mov.mid
# Loading  Bwv0938LittlePreluden6.mid
# Loading  Bwv0811EnglishSuiten64mov.mid
# Loading  Bwv1005ViolinSonatan31movAdagio.mid
# Loading  Bwv0529Sonateentrion5.mid
# Loading  Bwv0560ShortPreludeandFuguen8Spurious.mid
# Loading  Bwv0997PartitaforLute3mov.mid
# Loading  Bwv0537FantasiaandFugue.mid
# Loading  Bwv0806EnglishSuiten106mov.mid
# Loading  Bwv0559ShortPreludeandFuguen7Spurious1.mid
# Loading  Bwv0582PassacagliaandFugue.mid
# Loading  Bwv0933LittlePreluden11.mid
# Loading  Bwv0549PreludeandFugue.mid
# Loading  Bwv0543PreludeandFugue.mid
# Loading  Bwv0997PartitaforLute2mov.mid
# Loading  Bwv0554ShortPreludeandFuguen2Spurious.mid
# Loading  Bwv0568Prelude.mid
# Loading  Bwv1005ViolinSonatan33movLargo1.mid
# Loading  Bwv1014HarpsicordandViolinSonata2mov1.mid
# Loading  Bwv0570Fantasia.mid
# Loading  Bwv0811EnglishSuiten66mov.mid
# Loading  Bwv0811EnglishSuiten62mov1.mid
# Loading  Bwv1014HarpsicordandViolinSonata1mov.mid
# Loading  Bwv0551PreludeandFugue.mid
# Loading  Bwv1005ViolinSonatan32movFugue1.mid
# Loading  Bwv0558ShortPreludeandFuguen6Spurious.mid
# Loading  Bwv0527Sonateentrion3.mid
# Loading  Bwv0806EnglishSuiten103mov.mid
# Loading  Bwv0533PreludeandFugue.mid
# Loading  Bwv0555ShortPreludeandFuguen3Spurious.mid
# Loading  Bwv0815FrenchSuiten4.mid
# Loading  Bwv0816FrenchSuiten5.mid
# Loading  Bwv1046aSinfoniah.mid
# Loading  Bwv0997PartitaforLute1mov.mid
# Loading  Bwv1014HarpsicordandViolinSonata4mov.mid
# Loading  Bwv0556ShortPreludeandFuguen4Spurious1.mid
# Loading  Bwv0530Sonateentrion6.mid
# Loading  Bwv0936LittlePreluden4.mid
# Loading  Bwv0540ToccataandFugue.mid
# Loading  Bwv0811EnglishSuiten65mov.mid
# Loading  Bwv0963Sonata.mid
# Loading  Bwv0992Capriccio.mid
# Loading  Bwv1005ViolinSonatan34movAllegro.mid
# Loading  Bwv0546PreludeandFugue.mid
# Loading  Bwv0563Fantasieconimitation.mid
# Loading  Bwv0572Fantasia.mid
# Loading  Bwv0547PreludeandFugue.mid
# Loading  Bwv0532ToccataandFugue.mid
# Loading  Bwv0538ToccataandFugue_Dorian_.mid
# Loading  Bwv0590Pastorale.mid
# Loading  Bwv0998PreludeFugueAllegroforLute1mov.mid
# Loading  Bwv0556ShortPreludeandFuguen4Spurious.mid
# Loading  Bwv0806EnglishSuiten105mov.mid
# Loading  Bwv0528Sonateentrion4.mid
# Loading  Bwv0582PassacagliaandFugueOrchestral.mid
# Loading  Bwv0565ToccataandFugueInDmB.mid
# Loading  Bwv0593VivaldiConcertoArrangementRV522.mid
# Loading  Bwv0817FrenchSuiten6.mid
# Loading  Bwv0531PreludeandFugue.mid
# Loading  Bwv0536PreludeandFugue.mid
# Loading  Bwv0535PreludeandFugue.mid
# Loading  Bwv0542FantasiaandFugue.mid
# Loading  Bwv0811EnglishSuiten67mov.mid
# Loading  Bwv0806EnglishSuiten104mov.mid
# Loading  Bwv0996SuiteforLute1.mid
# Loading  Bwv0566PreludeandFugue.mid
# Loading  Bwv1014HarpsicordandViolinSonata2mov.mid
# Loading  Bwv0561FantasieandFuga.mid
# Loading  Bwv0996SuiteforLute.mid
# Loading  Bwv0998PreludeFugueAllegroforLute3mov.mid
# Loading  Bwv1005ViolinSonatan33movLargo.mid
# Loading  Bwv0811EnglishSuiten62mov.mid
# Loading  Bwv0557ShortPreludeandFuguen5Spurious.mid
# Loading  Bwv0806EnglishSuiten101mov.mid
# Loading  Bwv0997PartitaforLute5mov.mid
# Loading  Bwv0967Sonata.mid
# Loading  Bwv1005ViolinSonatan32movFugue.mid
# Loading  Bwv0541PreludeandFugue.mid
# Loading  Bwv0806EnglishSuiten110mov.mid
# Loading  Bwv0806EnglishSuiten109mov.mid
# Loading  Bwv0565ToccataandFugueInDmA.mid
# Loading  Bwv0811EnglishSuiten63mov.mid
# Loading  Bwv0935LittlePreluden3.mid
# Loading  Bwv0559ShortPreludeandFuguen7Spurious.mid
# Loading  Bwv0733FugaSopraMagnificat.mid
# Loading  Bwv0806EnglishSuiten102mov.mid
# Loading  Bwv1014HarpsicordandViolinSonata3mov.mid
# Loading  Bwv0906FantasiaandFugue.mid
# Loading  Bwv0594VivaldiConcertoArrangementRV208.mid
# Loading  Bwv0550PreludeandFugue.mid
# Loading  Bwv0997PartitaforLute4mov.mid
# Loading  Bwv0934LittlePreluden2.mid
# Loading  Bwv0552PreludeandFugue_StAnne_.mid
# Loading  Bwv0998PreludeFugueAllegroforLute2mov.mid
# Loading  Bwv0806EnglishSuiten108mov.mid
# Loading  Bwv0806EnglishSuiten107mov.mid
# Loading  Bwv0526Sonateentrion2.mid
# Loading  Bwv0525Sonateentrion1.mid
# Loading  Bwv0811EnglishSuiten61mov.mid
# Loading  AveMaria.mid
# Loading  Bwv0937LittlePreluden5.mid
# Loading  Bwv0933LittlePreluden1.mid
# Loading  PianoversionofBachstwopartinventionsNo5.mid
# Loading  PianoversionofBachstwopartinventionsNo9.mid
# Loading  PianoversionofBachstwopartinventionsNo14.mid
# Loading  PianoversionofBachstwopartinventionsNo8.mid
# Loading  JesuJoyofManDesiring.mid
# Loading  PianoversionofBachstwopartinventionsNo13.mid
# Loading  TocattoNo1inFSharpMinorBWV910.mid
# Loading  PianoversionofBachstwopartinventionsNo6.mid
# Loading  ToccataandFugueinDminorBWV565BusoniPianoArr.mid
# Loading  ClavierubungPart111DuetNo2inFMajor.mid
# Loading  PianoversionofBachstwopartinventionsNo11.mid
# Loading  PianoversionofBachstwopartinventionsNo.mid
# Loading  PreludeandFugueinCSharpBWV872.mid
# Loading  PianoversionofBachstwopartinventionsNo12.mid
# Loading  PianoversionofBachstwopartinventionsNo7.mid
# Loading  MinuetinG.mid
# Loading  PianoversionofBachstwopartinventionsNo4.mid
# Loading  PreludefromSonatan6.mid
# Loading  PianoversionofBachstwopartinventionsNo2.mid
# Loading  PianoversionofBachstwopartinventionsNo10.mid
# Loading  PianoversionofBachstwopartinventionsNo15.mid
# Loading  PreludeandFugueinD.mid
# Loading  PianoversionofBachstwopartinventionsNo3.mid
# Loading  PreludeandFugueinABWV888.mid
# Loading  Bwv802FourInventionsDuettosClavier-U_bungIIIn1.mid
# Loading  PianoversionofBachstwopartinventionsNo1.mid
# Loading  Bwv1056HarpsichordConcerton5.mid
# Loading  Bwv1055HarpsichordConcerton41mov.mid
# Loading  Bwv1058HarpsichordConcerton73mov.mid
# Loading  Bwv1064ThreeHarpsichordsConcerton23mov.mid
# Loading  Bwv1057HarpsichordConcerton62mov.mid
# Loading  Bwv1058HarpsichordConcerton71mov.mid
# Loading  Bwv1052HarpsichordConcerton12mov.mid
# Loading  Bwv1061TwoHarpsichordsConcerton2.mid
# Loading  Bwv1060TwoHarpsichordsConcerton1.mid
# Loading  Bwv1052HarpsichordConcerton1b.mid
# Loading  Bwv1053HarpsichordConcerton22mov.mid
# Loading  Bwv1055HarpsichordConcerton42mov.mid
# Loading  Bwv1054HarpsichordConcerton33mov.mid
# Loading  Bwv1054HarpsichordConcerton31mov.mid
# Loading  Bwv1062TwoHarpsichordsConcerton3.mid
# Loading  Bwv1058HarpsichordConcerton72mov.mid
# Loading  Bwv1054HarpsichordConcerton32mov.mid
# Loading  Bwv1065FourHarpsichordsConcerto.mid
# Loading  Bwv1052HarpsichordConcerton11mov.mid
# Loading  Bwv1057HarpsichordConcerton63mov.mid
# Loading  Bwv1053HarpsichordConcerton21mov.mid
# Loading  Bwv1053HarpsichordConcerton23mov.mid
# Loading  Bwv1052HarpsichordConcerton13mov.mid
# Loading  Bwv1064ThreeHarpsichordsConcerton22mov.mid
# Loading  Bwv1063ThreeHarpsichordsConcerton1.mid
# Loading  Bwv1055HarpsichordConcerton43mov.mid
# Loading  Bwv1064ThreeHarpsichordsConcerton21mov.mid
# Loading  Bwv1047BrandenburgConcertn23mov.mid
# Loading  Bwv1047BrandenburgConcertn22mov.mid
# Loading  Bwv1046BrandenburgConcertn12mov.mid
# Loading  Bwv1041ViolinConcerton12mov.mid
# Loading  Bwv1047BrandenburgConcertn21mov.mid
# Loading  Bwv1043TwoViolinsConcerton32mov.mid
# Loading  Bwv1051BrandenburgConcertn62mov.mid
# Loading  Bwv1049BrandenburgConcertn43mov.mid
# Loading  Bwv1048BrandenburgConcertn31mov.mid
# Loading  Bwv1051BrandenburgConcertn61mov.mid
# Loading  Bwv1043TwoViolinsConcerton33mov.mid
# Loading  Bwv1044FluteViolinandHarpsichordConcerto3mov.mid
# Loading  Bwv1046BrandenburgConcertn11mov.mid
# Loading  Bwv1051BrandenburgConcertn63mov.mid
# Loading  Bwv1042ViolinConcerton21mov.mid
# Loading  Bwv1044FluteViolinandHarpsichordConcerto1mov.mid
# Loading  Bwv1042ViolinConcerton22mov.mid
# Loading  Bwv1043TwoViolinsConcerton31mov.mid
# Loading  Bwv1049BrandenburgConcertn42mov.mid
# Loading  Bwv1046BrandenburgConcertn13mov.mid
# Loading  Bwv1042ViolinConcerton23mov.mid
# Loading  Bwv1041ViolinConcerton13mov.mid
# Loading  Bwv1041ViolinConcerton11mov.mid
# Loading  Bwv1049BrandenburgConcertn41mov.mid
# Loading  Bwv1044FluteViolinandHarpsichordConcerto2mov.mid
# Loading  CounterFuguen1.mid
# Loading  CounterFuguen2.mid
# Loading  CanonFuguen4.mid
# Loading  SimpleFugueRegularSubjectn1.mid
# Loading  CounterFuguen3.mid
# Loading  SimpleFugueInvertedSubjectn1.mid
# Loading  CanonFuguen2.mid
# Loading  MirrorFuguen1.mid
# Loading  DoubleFuguen2.mid
# Loading  CanonFuguen3.mid
# Loading  MirrorFuguen2.mid
# Loading  DoubleFuguen1.mid
# Loading  SimpleFugueInvertedSubjectn2.mid
# Loading  CanonFuguen1.mid
# Loading  TripleFuguen1.mid
# Loading  TheArtoftheFugueBWV1080.mid
# Loading  UnfinishedFugue.mid
# Loading  TripleFuguen2.mid
# Loading  SimpleFugueRegularSubjectn2.mid
# Loading  Bwv1067OrchestralSuiten27mov.mid
# Loading  Bwv1068OrchestralSuiten32mov.mid
# Loading  Bwv1066OrchestralSuiten13mov.mid
# Loading  Bwv1067OrchestralSuiten22mov.mid
# Loading  Bwv1069OrchestralSuiten45mov.mid
# Loading  Bwv1066OrchestralSuiten14mov.mid
# Loading  Bwv1069OrchestralSuiten43mov.mid
# Loading  Bwv1066OrchestralSuiten15mov.mid
# Loading  Bwv1068OrchestralSuiten35mov.mid
# Loading  Bwv1066OrchestralSuiten11mov.mid
# Loading  Bwv1067OrchestralSuiten23mov.mid
# Loading  Bwv1066OrchestralSuiten17mov.mid
# Loading  Bwv1068OrchestralSuiten33mov.mid
# Loading  Bwv1067OrchestralSuiten21mov.mid
# Loading  Bwv1067OrchestralSuiten24mov.mid
# Loading  Bwv1068OrchestralSuiten31mov.mid
# Loading  Bwv1069OrchestralSuiten41mov.mid
# Loading  Bwv1067OrchestralSuiten25mov.mid
# Loading  Bwv1067OrchestralSuiten26mov.mid
# Loading  Bwv1069OrchestralSuiten42mov.mid
# Loading  Bwv1066OrchestralSuiten16mov.mid
# Loading  Bwv1069OrchestralSuiten44mov.mid
# Loading  Bwv1068OrchestralSuiten34mov.mid
# Loading  Bwv1066OrchestralSuiten12mov.mid
# Loading  Variation18.mid
# Loading  Variation16.mid
# Loading  Variation19.mid
# Loading  Variation17.mid
# Loading  Variation13.mid
# Loading  Variation22.mid
# Loading  Variation21.mid
# Loading  Variation23.mid
# Loading  Variation14.mid
# Loading  Variation03.mid
# Loading  Variation01.mid
# Loading  Variation02.mid
# Loading  Variation07.mid
# Loading  Bwv108714Canons.mid
# Loading  Variation12.mid
# Loading  Variation27.mid
# Loading  Variation09.mid
# Loading  Variation11.mid
# Loading  Variation05.mid
# Loading  Variation28.mid
# Loading  Variation10.mid
# Loading  Variation04.mid
# Loading  Variation24.mid
# Loading  Variation00Aria.mid
# Loading  Variation26.mid
# Loading  Variation08.mid
# Loading  Variation25.mid
# Loading  Variation06.mid
# Loading  Variation29.mid
# Loading  Variation30.mid
# Loading  Variation15.mid
# Loading  Variation20.mid
# Loading  Wtcii01a.mid
# Loading  Wtcii18b.mid
# Loading  Wtcii06b.mid
# Loading  Wtcii17b.mid
# Loading  Wtcii22b.mid
# Loading  Wtcii10a.mid
# Loading  Wtcii20b.mid
# Loading  Wtcii23b.mid
# Loading  Wtcii12b.mid
# Loading  Wtcii09b.mid
# Loading  Wtcii10b.mid
# Loading  Wtcii08b.mid
# Loading  Wtcii15b.mid
# Loading  Wtcii21b.mid
# Loading  Wtcii24a.mid
# Loading  Wtcii24b.mid
# Loading  Wtcii14b.mid
# Loading  Wtcii11b.mid
# Loading  Wtcii19b.mid
# Loading  Wtcii07b.mid
# Loading  Wtcii16b.mid
# Loading  Wtcii13b.mid
# Loading  Wtcii01b.mid
# Loading  Wtcii11a.mid
# Loading  Wtcii03b.mid
# Loading  Wtcii02b.mid
# Loading  Wtcii05b.mid
# Loading  Wtcii04b.mid
# Loading  Bwv0799Sinfonian13.mid
# Loading  Bwv0787Sinfonian1.mid
# Loading  Bwv0796Sinfonian10.mid
# Loading  Bwv0788Sinfonian2.mid
# Loading  Bwv0800Sinfonian14.mid
# Loading  Bwv0801Sinfonian15.mid
# Loading  Bwv0793Sinfonian7.mid
# Loading  Bwv0794Sinfonian8.mid
# Loading  Bwv0789Sinfonian3.mid
# Loading  Bwv0792Sinfonian6.mid
# Loading  Bwv0798Sinfonian12.mid
# Loading  Bwv0790Sinfonian4.mid
# Loading  Bwv0791Sinfonian5.mid
# Loading  Bwv0797Sinfonian11.mid
# Loading  Bwv0795Sinfonian9.mid
# Loading  Bwv781Inventionn10.mid
# Loading  Bwv773Inventionn02.mid
# Loading  Bwv779Inventionn08.mid
# Loading  Bwv775Inventionn04.mid
# Loading  Bwv778Inventionn07.mid
# Loading  Bwv772Inventionn01.mid
# Loading  Bwv785Inventionn14.mid
# Loading  Bwv786Inventionn15.mid
# Loading  Bwv784Inventionn13.mid
# Loading  Bwv777Inventionn06.mid
# Loading  Bwv783Inventionn12.mid
# Loading  Bwv782Inventionn11.mid
# Loading  Bwv774Inventionn03.mid
# Loading  Bwv776Inventionn05.mid
# Loading  Bwv780Inventionn09.mid
# Loading  5ErbarmedichtmeinGottAltoAria.mid
# Loading  2AusLiebewillmeinHeilandsterbanSopranoAria.mid
# Loading  10WirsetzenunsmitTra_nenniederChorus.mid
# Loading  6HerzliebsterJesuChorus.mid
# Loading  8MachedichmeinherzBassAria.mid
# Loading  1BassAria.mid
# Loading  3GebtmirmeinenJesumweiderBassAria.mid
# Loading  7Ko_nnenTra_nenmeinerWangennichtserlangenAltoAria.mid
# Loading  4BlutenurduliebesHerzSopranoAria.mid
# Loading  9OHauptvollBlutundWundenChorus.mid
# Loading  10AriaQuoniam.mid
# Loading  21Benedictus.mid
# Loading  20Osanna.mid
# Loading  05AriaForSoprano.mid
# Loading  01KyrieEleison.mid
# Loading  13ChorPatremOmnipotentem.mid
# Loading  16EtRessurexit.mid
# Loading  07DuetDomineDeus.mid
# Loading  11ChorCumSancto.mid
# Loading  19Sanctus.mid
# Loading  09AriaQuiSedes.mid
# Loading  15EtIncarnatusCricifixus.mid
# Loading  12ChorCredoInUnumDeum.mid
# Loading  08ChorQuiTollis.mid
# Loading  18Confiteor.mid
# Loading  17BassAriaEtInSpritum.mid
# Loading  14DuetInUnum.mid
# Loading  06ChorGratiasAnimusTibi.mid
# Loading  22AgnusDei.mid
# Loading  04ChorGloriaInExelcis.mid
# Loading  02ChristeEleison.mid
# Loading  03KyrieEleison.mid
# Loading  23DonnaNobisPacem.mid
# Loading  013701b_.mid
# Loading  007706b_.mid
# Loading  004507b_.mid
# Loading  Bwv0286.mid
# Loading  007507b_.mid
# Loading  Bwv0207.mid
# Loading  Bwv02011.mid
# Loading  013703b_.mid
# Loading  008906b_.mid
# Loading  041400b_.mid
# Loading  028500b_.mid
# Loading  024515B_.mid
# Loading  069400b_.mid
# Loading  015309b_.mid
# Loading  038200b_.mid
# Loading  024415b_.mid
# Loading  024833b3.mid
# Loading  024846b5.mid
# Loading  036400b_.mid
# Loading  066800b_.mid
# Loading  010707b_.mid
# Loading  030000b_.mid
# Loading  024446b_.mid
# Loading  024864b6.mid
# Loading  024828b3.mid
# Loading  040400bv.mid
# Loading  032400b_.mid
# Loading  004106bs.mid
# Loading  032300b_.mid
# Loading  015301b_.mid
# Loading  035300b_.mid
# Loading  033900b_.mid
# Loading  Bwv0048.mid
# Loading  040600b_.mid
# Loading  064800b_.mid
# Loading  003907b_.mid
# Loading  014406b_.mid
# Loading  031300b_.mid
# Loading  027400b_.mid
# Loading  024462b_.mid
# Loading  026700ba.mid
# Loading  013705b_.mid
# Loading  017206vn.mid
# Loading  012805b_.mid
# Loading  026700b_.mid
# Loading  030700b_.mid
# Loading  030900b_.mid
# Loading  014806bv.mid
# Loading  030200b_.mid
# Loading  004803b_.mid
# Loading  069100orn.mid
# Loading  007011ch.mid
# Loading  030400b_.mid
# Loading  017705bv.mid
# Loading  009005b_.mid
# Loading  025200b_.mid
# Loading  032200b_.mid
# Loading  Bwv03624.mid
# Loading  014608b_.mid
# Loading  Bwv0298.mid
# Loading  033200b_.mid
# Loading  033400b_.mid
# Loading  013006b_.mid
# Loading  003907bv.mid
# Loading  003706b_.mid
# Loading  036500b_.mid
# Loading  076902b_.mid
# Loading  Bwv0097.mid
# Loading  014505b_.mid
# Loading  041500b_.mid
# Loading  070100b_.mid
# Loading  024425b_.mid
# Loading  065700b_.mid
# Loading  005505b_.mid
# Loading  043800b_.mid
# Loading  065900b_.mid
# Loading  032800b_.mid
# Loading  014004b_.mid
# Loading  011407b_.mid
# Loading  033800b_.mid
# Loading  066300b_.mid
# Loading  034500b_.mid
# Loading  039100b_.mid
# Loading  004008b_.mid
# Loading  010107b_.mid
# Loading  006707b_.mid
# Loading  037000b_.mid
# Loading  065600b_.mid
# Loading  028600b_.mid
# Loading  009507b_.mid
# Loading  010602b_.mid
# Loading  Bwv0026.mid
# Loading  016806b_.mid
# Loading  076905b_.mid
# Loading  007607b_.mid
# Loading  022602bv.mid
# Loading  031600b_.mid
# Loading  Bwv0016.mid
# Loading  024503b_.mid
# Loading  033500bv.mid
# Loading  015905b_.mid
# Loading  035400b_.mid
# Loading  016406b_.mid
# Loading  010806b_.mid
# Loading  028300b_.mid
# Loading  033700b_.mid
# Loading  034600b_.mid
# Loading  010406b_.mid
# Loading  024853b5.mid
# Loading  018305b_.mid
# Loading  006507b_.mid
# Loading  066500b_.mid
# Loading  034700b_.mid
# Loading  041600b_.mid
# Loading  031200b_.mid
# Loading  060800qt.mid
# Loading  011704v1.mid
# Loading  076901b_.mid
# Loading  010107bv.mid
# Loading  016606b_.mid
# Loading  029500b_.mid
# Loading  009106b_.mid
# Loading  037300bv.mid
# Loading  066800com.mid
# Loading  Bwv018a5.mid
# Loading  025600b_.mid
# Loading  039400b_.mid
# Loading  006206b_.mid
# Loading  040400b_.mid
# Loading  Bwv0066.mid
# Loading  025100b_.mid
# Loading  Bwv0256.mid
# Loading  004807b_.mid
# Loading  043500b_.mid
# Loading  030300b_.mid
# Loading  040800b_.mid
# Loading  032900b_.mid
# Loading  022709b_.mid
# Loading  025400b_.mid
# Loading  013506b_.mid
# Loading  036800b_.mid
# Loading  018707b_.mid
# Loading  039900b_.mid
# Loading  033300b_.mid
# Loading  030600b_.mid
# Loading  026300b_.mid
# Loading  010506b_.mid
# Loading  024310b_.mid
# Loading  024809b1.mid
# Loading  024417b_.mid
# Loading  037100b_.mid
# Loading  039500b_.mid
# Loading  041300b_.mid
# Loading  017807b_.mid
# Loading  009207b_.mid
# Loading  007807b_.mid
# Loading  019007ch.mid
# Loading  Bwv0197ch.mid
# Loading  064700b_.mid
# Loading  028100b_.mid
# Loading  014001b_.mid
# Loading  031500b_.mid
# Loading  027700b_.mid
# Loading  043100b_.mid
# Loading  008008b_.mid
# Loading  027800b_.mid
# Loading  Bwv0326.mid
# Loading  037400b_.mid
# Loading  033600b_.mid
# Loading  065400b_.mid
# Loading  007408b_.mid
# Loading  024514b_.mid
# Loading  013606b_.mid
# Loading  028800b_.mid
# Loading  015305b_.mid
# Loading  034100b_.mid
# Loading  032500b_.mid
# Loading  040100b_.mid
# Loading  026200b_.mid
# Loading  038700b_.mid
# Loading  Bwv0127.mid
# Loading  070000b_.mid
# Loading  043000b_.mid
# Loading  Bwv0063.mid
# Loading  016907b_.mid
# Loading  026600b_.mid
# Loading  Bwv0057.mid
# Loading  022711b_.mid
# Loading  037300b_.mid
# Loading  034800b_.mid
# Loading  007206b_.mid
# Loading  024537b_.mid
# Loading  033100b_.mid
# Loading  042200b_.mid
# Loading  038800b_.mid
# Loading  066100b_.mid
# Loading  024842bs.mid
# Loading  028200b_.mid
# Loading  006606b_.mid
# Loading  014007b_.mid
# Loading  036700b_.mid
# Loading  065100b_.mid
# Loading  041200b_.mid
# Loading  024528b_.mid
# Loading  011606b_.mid
# Loading  038300b_.mid
# Loading  037200b_.mid
# Loading  028000b_.mid
# Loading  010306b_.mid
# Loading  024410b_.mid
# Loading  024505b_.mid
# Loading  034900b_.mid
# Loading  036100b_.mid
# Loading  019707ba.mid
# Loading  065300b_.mid
# Loading  Bwv0166.mid
# Loading  037600b_.mid
# Loading  026800b_.mid
# Loading  041800b_.mid
# Loading  024809bs.mid
# Loading  031100b_.mid
# Loading  019007b_.mid
# Loading  017405b_.mid
# Loading  037700b_.mid
# Loading  027000b_.mid
# Loading  006206bv.mid
# Loading  007514b_.mid
# Loading  014505bv.mid
# Loading  030500b_.mid
# Loading  Bwv0177.mid
# Loading  014403b_.mid
# Loading  034000b_.mid
# Loading  Bwv0185.mid
# Loading  029800b_.mid
# Loading  010006b_.mid
# Loading  009906b_.mid
# Loading  007906b_.mid
# Loading  Bwv0256v2.mid
# Loading  009307b_.mid
# Loading  015606b_.mid
# Loading  036200b_.mid
# Loading  012006b_.mid
# Loading  008107b_.mid
# Loading  027100b_.mid
# Loading  065500b_.mid
# Loading  003806b_.mid
# Loading  011704b_.mid
# Loading  017606b_.mid
# Loading  027600b_.mid
# Loading  015105b_.mid
# Loading  024842b4.mid
# Loading  027500b_.mid
# Loading  040700b_.mid
# Loading  006906b_.mid
# Loading  026400b_.mid
# Loading  033500b_.mid
# Loading  064200b_.mid
# Loading  004705b_.mid
# Loading  011506b_.mid
# Loading  Bwv0276.mid
# Loading  042700b_.mid
# Loading  004207b_.mid
# Loading  018405b_.mid
# Loading  025900b_.mid
# Loading  027300b_.mid
# Loading  024437b_.mid
# Loading  066600b_.mid
# Loading  028900b_.mid
# Loading  024517b_.mid
# Loading  043300b_.mid
# Loading  066400b_.mid
# Loading  041100b_.mid
# Loading  017507ch.mid
# Loading  Bwv0048v.mid
# Loading  042400b_.mid
# Loading  012705b_.mid
# Loading  043700b_.mid
# Loading  019412b_.mid
# Loading  042000b_.mid
# Loading  012606bv.mid
# Loading  008606b_.mid
# Loading  024823b2.mid
# Loading  017507b_.mid
# Loading  004606b_.mid
# Loading  013906b_.mid
# Loading  019406bv.mid
# Loading  037900b_.mid
# Loading  032600b_.mid
# Loading  005903b_.mid
# Loading  039700b_.mid
# Loading  076904b_.mid
# Loading  040900b_.mid
# Loading  011106b_.mid
# Loading  043400b_.mid
# Loading  041000b_.mid
# Loading  035900b_.mid
# Loading  019406b_.mid
# Loading  036900b_.mid
# Loading  041700b_.mid
# Loading  007614b_.mid
# Loading  040000b_.mid
# Loading  031800b_.mid
# Loading  029900b_.mid
# Loading  037500b_.mid
# Loading  039200b_.mid
# Loading  008807b_.mid
# Loading  066000b_.mid
# Loading  Bwv001.mid
# Loading  Bwv0306.mid
# Loading  Bwv0197.mid
# Loading  029600b_.mid
# Loading  019705b_.mid
# Loading  012606b_.mid
# Loading  042600b_.mid
# Loading  043200b_.mid
# Loading  005605b_.mid
# Loading  012406b_.mid
# Loading  Bwv0256v1.mid
# Loading  024823bs.mid
# Loading  028700b_.mid
# Loading  017206b_.mid
# Loading  026000b_.mid
# Loading  014907b_.mid
# Loading  024440b_.mid
# Loading  064900b_.mid
# Loading  042300b_.mid
# Loading  008707b_.mid
# Loading  012008ba.mid
# Loading  012206b_.mid
# Loading  Bwv0336.mid
# Loading  039600b_.mid
# Loading  026500b_.mid
# Loading  Bwv0077.mid
# Loading  013705ch.mid
# Loading  069000b_.mid
# Loading  029100b_.mid
# Loading  006906bav.mid
# Loading  006402b_.mid
# Loading  007305b_.mid
# Loading  019506b_.mid
# Loading  031000b_.mid
# Loading  018007bv.mid
# Loading  009106ch.mid
# Loading  014907ch.mid
# Loading  006704b_.mid
# Loading  035200b_.mid
# Loading  042900b_.mid
# Loading  Bwv0306v.mid
# Loading  018806b_.mid
# Loading  031700b_.mid
# Loading  005708b_.mid
# Loading  004407b_.mid
# Loading  040300b_.mid
# Loading  037800b_.mid
# Loading  109100b_.mid
# Loading  030800b_.mid
# Loading  031400b_.mid
# Loading  027900b_.mid
# Loading  017206ch.mid
# Loading  024526b_.mid
# Loading  Bwv0266.mid
# Loading  038400b_.mid
# Loading  024432b_.mid
# Loading  024835b3.mid
# Loading  025300b_.mid
# Loading  076903b_.mid
# Loading  Bwv0246s.mid
# Loading  024454b_.mid
# Loading  004606bs.mid
# Loading  015403b_.mid
# Loading  032100b_.mid
# Loading  042800b_.mid
# Loading  012306b_.mid
# Loading  025800b_.mid
# Loading  018405bv.mid
# Loading  009408b_.mid
# Loading  004003b_.mid
# Loading  060600b_.mid
# Loading  008305b_.mid
# Loading  011704v2.mid
# Loading  006408b_.mid
# Loading  029200b_.mid
# Loading  035600b_.mid
# Loading  011308b_.mid
# Loading  043600b_.mid
# Loading  016106b_.mid
# Loading  069100b_.mid
# Loading  024540b_.mid
# Loading  040500b_.mid
# Loading  028400b_.mid
# Loading  006502b_.mid
# Loading  035800b_.mid
# Loading  029000b_.mid
# Loading  024429bb.mid
# Loading  Bwv0107.mid
# Loading  022602b_.mid
# Loading  007007b_.mid
# Loading  035500b_.mid
# Loading  015505b_.mid
# Loading  Bwv0036.mid
# Loading  024817b2.mid
# Loading  064600b_.mid
# Loading  065000b_.mid
# Loading  025700b_.mid
# Loading  026900b_.mid
# Loading  011506bv.mid
# Loading  040200b_.mid
# Loading  018506b_.mid
# Loading  073300b_.mid
# Loading  035100b_.mid
# Loading  035000b_.mid
# Loading  065200b_.mid
# Loading  022902b_.mid
# Loading  007011b_.mid
# Loading  017106b_.mid
# Loading  009801b_.mid
# Loading  Bwv0319.mid
# Loading  011909b_.mid
# Loading  013807b_.mid
# Loading  017906b_.mid
# Loading  035700b_.mid
# Loading  Bwv0136.mid
# Loading  029300b_.mid
# Loading  013306b_.mid
# Loading  Bwv0086.mid
# Loading  033000b_.mid
# Loading  041900b_.mid
# Loading  012106b_.mid
# Loading  024864bs.mid
# Loading  007903bs.mid
# Loading  029700b_.mid
# Loading  017705b_.mid
# Loading  024462bv.mid
# Loading  034400b_.mid
# Loading  Bwv03628.mid
# Loading  009606b_.mid
# Loading  006906ba.mid
# Loading  025500b_.mid
# Loading  026100b_.mid
# Loading  024805b1.mid
# Loading  015408b_.mid
# Loading  006106b_.mid
# Loading  034200b_.mid
# Loading  019710b_.mid
# Loading  010207b_.mid
# Loading  060800b_.mid
# Loading  010406bv.mid
# Loading  006005b_.mid
# Loading  015804b_.mid
# Loading  031900b_.mid
# Loading  065800b_.mid
# Loading  027200b_.mid
# Loading  008405b_.mid
# Loading  005206b_.mid
# Loading  013702b_.mid
# Loading  011205b_.mid
# Loading  024415bv.mid
# Loading  007903b_.mid
# Loading  066700b_.mid
# Loading  022701b_.mid
# Loading  051000b_.mid
# Loading  Bwv0116.mid
# Loading  004006b_.mid
# Loading  042100b_.mid
# Loading  024812b2.mid
# Loading  025000b_.mid
# Loading  012506b_.mid
# Loading  073800b_.mid
# Loading  036300b_.mid
# Loading  038900b_.mid
# Loading  009209b_.mid
# Loading  032000b_.mid
# Loading  042500b_.mid
# Loading  039000b_.mid
# Loading  064500b_.mid
# Loading  034300b_.mid
# Loading  Bwv0145.mid
# Loading  039800b_.mid
# Loading  040900bv.mid
# Loading  004311b_.mid
# Loading  038100b_.mid
# Loading  012905b_.mid
# Loading  022707b_.mid
# Loading  039300b_.mid
# Loading  016206b_.mid
# Loading  016506b_.mid
# Loading  038600b_.mid
# Loading  024511b_.mid
# Loading  024417bv.mid
# Loading  066200b_.mid
# Loading  022703b_.mid
# Loading  015705b_.mid
# Loading  007305bv.mid
# Loading  009709b_.mid
# Loading  018007b_.mid
# Loading  024859b6.mid
# Loading  006404b_.mid
# Loading  029400b_.mid
# Loading  008506b_.mid
# Loading  032700b_.mid
# Loading  024522b_.mid
# Loading  014500ba.mid
# Loading  024864qt.mid
# Loading  038000b_.mid
# Loading  024444b_.mid
# Loading  011007b_.mid
# Loading  030100b_.mid
# Loading  014706b_.mid
# Loading  Bwv0036v.mid
# Loading  036600b_.mid
# Loading  Bwv0298ch.mid
# Loading  004106b_.mid
# Loading  Bwv0246.mid
# Loading  038500b_.mid
# Loading  009709ch.mid
# Loading  024403b_.mid
# Loading  014710b_.mid
# Loading  036000b_.mid
# Loading  014806b_.mid
# Loading  05Polonaise.mid
# Loading  16Marche.mid
# Loading  13Marche.mid
# Loading  12Polonaise.mid
# Loading  02Menuet.mid
# Loading  06Menuet.mid
# Loading  10Menuet.mid
# Loading  03Menuet.mid
# Loading  14Polonaise.mid
# Loading  15Musette.mid
# Loading  17Polonaise.mid
# Loading  09Menuet.mid
# Loading  01Menuet.mid
# Loading  08Polonaise.mid
# Loading  04Menuet.mid
# Loading  11Marche.mid
# Loading  07Rondo.mid
#
# Successfully loaded and processed 884 Bach MIDI files.

# %%
# We now should have a dictionary for each composer, where the dictionary stores the MIDI data along with
# the (cleaned) filename for that MIDI file.


print()
print(" There are ", len(mozart_midi_data), "MIDI files for Mozart that have been loaded")
print()
print(" There are ", len(chopin_midi_data), "MIDI files for Chopin that have been loaded")
print()
print(" There are ", len(beethoven_midi_data), "MIDI files for Beethoven that have been loaded")
print()
print(" There are ", len(bach_midi_data), "MIDI files for Bach that have been loaded")
# Out:
#  There are  219 MIDI files for Mozart that have been loaded
#
#  There are  136 MIDI files for Chopin that have been loaded
#
#  There are  211 MIDI files for Beethoven that have been loaded
#
#  There are  884 MIDI files for Bach that have been loaded

# %% [markdown]
# # Feature Extraction

# %%
# Convert dict → list of dicts with filename + midi
formatted_mozart = [{"filename": fname, "midi": midi} for fname, midi in mozart_midi_data.items()]
formatted_chopin = [{"filename": fname, "midi": midi} for fname, midi in chopin_midi_data.items()]
formatted_beethoven = [{"filename": fname, "midi": midi} for fname, midi in beethoven_midi_data.items()]
formatted_bach = [{"filename": fname, "midi": midi} for fname, midi in bach_midi_data.items()]

# %%
composer_map = {
    "Mozart": (formatted_mozart, 0),
    "Chopin": (formatted_chopin, 1),
    "Beethoven": (formatted_beethoven, 2),
    "Bach": (formatted_bach, 3)
}

all_data = []
labels = []

for composer, (midi_list, label) in composer_map.items():
    for entry in midi_list:
        midi_obj = entry["midi"]  # Now works perfectly
        all_data.append(midi_obj)
        labels.append(label)

# %%
import numpy as np

def midi_to_fixed_roll(midi, fs=10, max_len=500):
    """
    Convert a pretty_midi.PrettyMIDI object to a fixed-size piano roll.

    Parameters:
    -----------
    midi : pretty_midi.PrettyMIDI
        The parsed MIDI object.
    fs : int, optional (default=10)
        Frames per second for piano roll resolution.
    max_len : int, optional (default=500)
        The maximum number of time steps to keep.
        Rolls shorter than this will be zero-padded.

    Returns:
    --------
    roll : np.ndarray
        A 2D array of shape (128, max_len), normalized to [0,1].
        Returns None if the MIDI file has no notes.
    """
    try:
        roll = midi.get_piano_roll(fs=fs)  # Shape = (128, time_steps)

        # Skip empty MIDI (no active notes)
        if roll.shape[1] == 0 or np.max(roll) == 0:
            return None

        # Crop or pad to fixed length
        roll = roll[:, :max_len]
        if roll.shape[1] < max_len:
            pad = max_len - roll.shape[1]
            roll = np.pad(roll, ((0, 0), (0, pad)), mode='constant')

        # Normalize velocities to [0,1]
        return roll / 127.0

    except Exception as e:
        print(f"Error converting MIDI to piano roll: {e}")
        return None

# %%
roll = midi_to_fixed_roll(all_data[0])
if roll is not None:
    print("Piano roll shape:", roll.shape)  # Should be (128, 500)
    print("Max value (should be <= 1):", np.max(roll))
else:
    print("MIDI had no notes.")
# Out:
# Piano roll shape: (128, 500)
# Max value (should be <= 1): 5.866141732283465

# %% [markdown]
# Need to convert the MIDI files into piano roll for CNN models

# %%
import numpy as np

X = []
y = []

for i, midi in enumerate(all_data):
    roll = midi_to_fixed_roll(midi, fs=10, max_len=500)
    if roll is not None:
        X.append(roll)
        y.append(labels[i])
    else:
        print(f"⚠️ Skipping file #{i} — piano roll conversion failed")

X = np.array(X)
X = X[..., np.newaxis]  # shape → (samples, 128, 500, 1)
y = np.array(y)

# %%
print("✅ Total samples:", X.shape[0])
print("📐 Input shape (should be samples, 128, 500, 1):", X.shape)
print("🎯 Label shape:", y.shape)
print("Unique classes:", np.unique(y))
# Out:
# ✅ Total samples: 1450
# 📐 Input shape (should be samples, 128, 500, 1): (1450, 128, 500, 1)
# 🎯 Label shape: (1450,)
# Unique classes: [0 1 2 3]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from tensorflow.keras.layers import GlobalAveragePooling2D

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 500, 1)),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    GlobalAveragePooling2D(),  # Instead of Flatten()
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(4, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 498, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 249, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 247, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 123, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 121, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 60, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,700 (428.52 KB)
#  Trainable params: 109,700 (428.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.5616 - loss: 1.2410 - val_accuracy: 0.5948 - val_loss: 1.1084
# Epoch 2/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.6074 - loss: 1.1055 - val_accuracy: 0.5948 - val_loss: 1.1025
# Epoch 3/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.5815 - loss: 1.1363 - val_accuracy: 0.5948 - val_loss: 1.0938
# Epoch 4/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.5895 - loss: 1.1109 - val_accuracy: 0.5948 - val_loss: 1.0752
# Epoch 5/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.6300 - loss: 1.0314 - val_accuracy: 0.5948 - val_loss: 1.0601
# Epoch 6/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.6275 - loss: 1.0290 - val_accuracy: 0.5948 - val_loss: 1.0306
# Epoch 7/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6040 - loss: 1.0371 - val_accuracy: 0.5948 - val_loss: 1.0400
# Epoch 8/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.6125 - loss: 1.0002 - val_accuracy: 0.5948 - val_loss: 0.9729
# Epoch 9/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.5916 - loss: 0.9941 - val_accuracy: 0.5948 - val_loss: 0.9677
# Epoch 10/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6072 - loss: 0.9329 - val_accuracy: 0.6810 - val_loss: 0.8702
# Epoch 11/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.6393 - loss: 0.8586 - val_accuracy: 0.7069 - val_loss: 0.8471
# Epoch 12/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.6677 - loss: 0.8146 - val_accuracy: 0.7069 - val_loss: 0.7329
# Epoch 13/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.6942 - loss: 0.7558 - val_accuracy: 0.7069 - val_loss: 0.7167
# Epoch 14/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6733 - loss: 0.7406 - val_accuracy: 0.7414 - val_loss: 0.6940
# Epoch 15/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.7104 - loss: 0.7163 - val_accuracy: 0.7241 - val_loss: 0.6747
# Epoch 16/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.7192 - loss: 0.6813 - val_accuracy: 0.6724 - val_loss: 0.6964
# Epoch 17/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.7216 - loss: 0.6989 - val_accuracy: 0.7155 - val_loss: 0.6754
# Epoch 18/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.7093 - loss: 0.6647 - val_accuracy: 0.6466 - val_loss: 0.7681
# Epoch 19/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.7016 - loss: 0.7074 - val_accuracy: 0.7069 - val_loss: 0.6587
# Epoch 20/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.6873 - loss: 0.6972 - val_accuracy: 0.6983 - val_loss: 0.6563

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"🎯 Test Accuracy: {test_acc:.2%}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.7199 - loss: 0.7285
# 🎯 Test Accuracy: 71.72%

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Loss plot
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# Get predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Show confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=["Mozart", "Chopin", "Beethoven", "Bach"])
disp.plot(cmap="Blues")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step

# %% [markdown]
# Data balance augmentation

# %%
import numpy as np
from collections import Counter
from tqdm import tqdm

def transpose_roll(roll, semitone_shift):
    if semitone_shift == 0:
        return roll
    shifted = np.roll(roll, shift=semitone_shift, axis=0)
    if semitone_shift > 0:
        shifted[:semitone_shift, :] = 0
    else:
        shifted[semitone_shift:, :] = 0
    return shifted

def balance_dataset_with_augmentation(X_raw, y_raw, target_classes=[0, 1, 2, 3], max_shifts=[-2, -1, 1, 2]):
    print("📊 Original class distribution:")
    class_counts = Counter(y_raw)
    for label in sorted(class_counts):
        print(f"  Class {label}: {class_counts[label]} samples")

    max_count = max(class_counts.values())

    X_aug = []
    y_aug = []

    for class_label in sorted(set(y_raw)):
        class_indices = [i for i, y in enumerate(y_raw) if y == class_label]
        class_samples = [X_raw[i] for i in class_indices]

        # Add original samples
        X_aug.extend(class_samples)
        y_aug.extend([class_label] * len(class_samples))

        needed = max_count - len(class_samples)
        if needed <= 0:
            continue  # Already at or above max

        print(f"🔁 Augmenting class {class_label}: need {needed} more samples")

        count = 0
        while count < needed:
            for i in range(len(class_samples)):
                if count >= needed:
                    break
                shift = np.random.choice(max_shifts)
                new_sample = transpose_roll(class_samples[i], shift)
                X_aug.append(new_sample)
                y_aug.append(class_label)
                count += 1

    print("\n✅ Final class distribution after augmentation:")
    new_counts = Counter(y_aug)
    for label in sorted(new_counts):
        print(f"  Class {label}: {new_counts[label]} samples")

    X_aug = np.array(X_aug)[..., np.newaxis]  # Add channel dim
    y_aug = np.array(y_aug)
    return X_aug, y_aug

# %%
X_balanced, y_balanced = balance_dataset_with_augmentation(X, y)
# Out:
# 📊 Original class distribution:
#   Class 0: 219 samples
#   Class 1: 136 samples
#   Class 2: 211 samples
#   Class 3: 884 samples
# 🔁 Augmenting class 0: need 665 more samples
# 🔁 Augmenting class 1: need 748 more samples
# 🔁 Augmenting class 2: need 673 more samples
#
# ✅ Final class distribution after augmentation:
#   Class 0: 884 samples
#   Class 1: 884 samples
#   Class 2: 884 samples
#   Class 3: 884 samples

# %%
# Redefine the model before retraining
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 500, 1)),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    GlobalAveragePooling2D(),

    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(4, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 126, 498, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 63, 249, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 61, 247, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 30, 123, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 28, 121, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 14, 60, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,700 (428.52 KB)
#  Trainable params: 109,700 (428.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_balanced, y_balanced, test_size=0.2, stratify=y_balanced, random_state=42)

# %%
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 14s 129ms/step - accuracy: 0.2628 - loss: 1.3745 - val_accuracy: 0.3004 - val_loss: 1.3469
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.3718 - loss: 1.3257 - val_accuracy: 0.3463 - val_loss: 1.3102
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.4012 - loss: 1.2602 - val_accuracy: 0.4700 - val_loss: 1.2142
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.4695 - loss: 1.1671 - val_accuracy: 0.5124 - val_loss: 1.0329
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.5232 - loss: 1.0231 - val_accuracy: 0.5230 - val_loss: 1.0258
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.5625 - loss: 1.0161 - val_accuracy: 0.5088 - val_loss: 1.0584
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.5876 - loss: 0.9275 - val_accuracy: 0.5901 - val_loss: 0.9177
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.5962 - loss: 0.8790 - val_accuracy: 0.6007 - val_loss: 0.8946
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.6200 - loss: 0.8415 - val_accuracy: 0.6254 - val_loss: 0.8601
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.6234 - loss: 0.8156 - val_accuracy: 0.6396 - val_loss: 0.8255
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.6615 - loss: 0.7789 - val_accuracy: 0.6749 - val_loss: 0.7705
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.6636 - loss: 0.7291 - val_accuracy: 0.6396 - val_loss: 0.8320
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.6720 - loss: 0.7365 - val_accuracy: 0.6678 - val_loss: 0.7752
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.6715 - loss: 0.7544 - val_accuracy: 0.6184 - val_loss: 0.8912
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.6831 - loss: 0.7437 - val_accuracy: 0.7173 - val_loss: 0.7130
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.7362 - loss: 0.6381 - val_accuracy: 0.6537 - val_loss: 0.8437
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.6947 - loss: 0.7012 - val_accuracy: 0.6537 - val_loss: 0.8091
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.7317 - loss: 0.6304 - val_accuracy: 0.7208 - val_loss: 0.6722
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.7482 - loss: 0.6002 - val_accuracy: 0.7420 - val_loss: 0.6179
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.7622 - loss: 0.5843 - val_accuracy: 0.7244 - val_loss: 0.6269

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"🎯 Test Accuracy: {test_acc:.2%}")
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7207 - loss: 0.6489
# 🎯 Test Accuracy: 72.60%

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Loss plot
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# Get predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Show confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=["Mozart", "Chopin", "Beethoven", "Bach"])
disp.plot(cmap="Blues")
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=["Mozart", "Chopin", "Beethoven", "Bach"]))
# Out:
#               precision    recall  f1-score   support
#
#       Mozart       0.66      0.60      0.63       177
#       Chopin       0.87      0.76      0.81       177
#    Beethoven       0.56      0.70      0.62       177
#         Bach       0.87      0.85      0.86       177
#
#     accuracy                           0.73       708
#    macro avg       0.74      0.73      0.73       708
# weighted avg       0.74      0.73      0.73       708

# %% [markdown]
# Model rebuild for feature extraction to be used in LSTM

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout

input_layer = Input(shape=(128, 500, 1))
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2), name='max_pooling2d_1')(x)

x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2), name='max_pooling2d_2')(x)

x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2), name='max_pooling2d_3')(x)

x = MaxPooling2D((2, 2), name='max_pooling2d_4')(x)  # Shape: (None, 14, 60, 128) for piano roll input

# 💡 Save this point for extraction:
cnn_features = x  # (14, 60, 128)

# Classification layers
x = GlobalAveragePooling2D()(cnn_features)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(4, activation='softmax')(x)

# Final model
model = Model(inputs=input_layer, outputs=output)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 128, 500, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 126, 498, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 63, 249, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 61, 247, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 123, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 28, 121, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 60, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 30, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,700 (428.52 KB)
#  Trainable params: 109,700 (428.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 99ms/step - accuracy: 0.2500 - loss: 1.3757 - val_accuracy: 0.3074 - val_loss: 1.3351
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4004 - loss: 1.2979 - val_accuracy: 0.3145 - val_loss: 1.2590
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4785 - loss: 1.1932 - val_accuracy: 0.5194 - val_loss: 1.0233
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.5515 - loss: 0.9814 - val_accuracy: 0.5371 - val_loss: 1.0731
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.5491 - loss: 1.0010 - val_accuracy: 0.5230 - val_loss: 0.9356
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.5869 - loss: 0.9152 - val_accuracy: 0.5830 - val_loss: 0.9850
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.6068 - loss: 0.8731 - val_accuracy: 0.6466 - val_loss: 0.8486
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.6187 - loss: 0.8197 - val_accuracy: 0.6360 - val_loss: 0.8032
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.6351 - loss: 0.7902 - val_accuracy: 0.6148 - val_loss: 0.8211
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.6576 - loss: 0.7782 - val_accuracy: 0.6784 - val_loss: 0.7476
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.6664 - loss: 0.7398 - val_accuracy: 0.7102 - val_loss: 0.7187
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.7020 - loss: 0.6956 - val_accuracy: 0.6360 - val_loss: 0.8224
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.7045 - loss: 0.6759 - val_accuracy: 0.6325 - val_loss: 0.8809
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.6969 - loss: 0.6656 - val_accuracy: 0.7173 - val_loss: 0.6726
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.7441 - loss: 0.5965 - val_accuracy: 0.7279 - val_loss: 0.6848
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.7468 - loss: 0.6051 - val_accuracy: 0.7385 - val_loss: 0.6463
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.7398 - loss: 0.6066 - val_accuracy: 0.7703 - val_loss: 0.5979
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.7637 - loss: 0.5579 - val_accuracy: 0.7668 - val_loss: 0.6092
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.7828 - loss: 0.5234 - val_accuracy: 0.7774 - val_loss: 0.5847
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.7973 - loss: 0.5083 - val_accuracy: 0.7845 - val_loss: 0.5444

# %%
feature_extractor = Model(
    inputs=model.input,
    outputs=model.get_layer("max_pooling2d_4").output
)

features = feature_extractor.predict(X_balanced, batch_size=32, verbose=1)
print("Extracted feature shape:", features.shape)  # (samples, 14, 60, 128)
# Out:
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step
# Extracted feature shape: (3536, 7, 30, 128)

# %% [markdown]
# Extracted feature

# %%
X_lstm = features.transpose(0, 2, 1, 3).reshape(features.shape[0], 30, 7 * 128)

print("X_lstm shape:", X_lstm.shape)  # ➞ (3536, 30, 896)
# Out:
# X_lstm shape: (3536, 30, 896)

# %%
import numpy as np
import os
from google.colab import drive


# Specify the path to your Google Drive where you want to save the files
# You might want to change this path to a specific folder in your Drive
drive_save_path = '/content/drive/My Drive/Colab Notebooks' # Example path, change as needed

# Create the directory if it doesn't exist
os.makedirs(drive_save_path, exist_ok=True)

# Save the files to the specified Google Drive path
np.save(os.path.join(drive_save_path, "X_lstm.npy"), X_lstm)
np.save(os.path.join(drive_save_path, "y_balanced.npy"), y_balanced)

print(f"Files saved to {drive_save_path}")
# Out:
# Files saved to /content/drive/My Drive/Colab Notebooks
